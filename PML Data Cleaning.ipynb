# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
HrData=pd.read_csv('dataset.csv')

# %%
HrData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5180 entries, 0 to 5179
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   EmployeeID          5180 non-null   int64
#  1   Attrition           5180 non-null   int64
#  2   Age                 4864 non-null   float64
#  3   TravelProfile       5180 non-null   object
#  4   Department          5056 non-null   object
#  5   HomeToWork          4925 non-null   float64
#  6   EducationField      5180 non-null   object
#  7   Gender              5134 non-null   object
#  8   HourlnWeek          4893 non-null   float64
#  9   Involvement         5180 non-null   int64
#  10  WorkLifeBalance     5180 non-null   int64
#  11  Designation         5142 non-null   object
#  12  JobSatisfaction     5180 non-null   int64
#  13  ESOPs               5180 non-null   int64
#  14  NumCompaniesWorked  5180 non-null   int64
# ...

# %%
HrData['EmployeeID'].isna().value_counts()
# Out:
# EmployeeID
# False    5180
# Name: count, dtype: int64

# %%
HrData.loc[HrData['EmployeeID'].isna()==True].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   EmployeeID          0 non-null      int64
#  1   Attrition           0 non-null      int64
#  2   Age                 0 non-null      float64
#  3   TravelProfile       0 non-null      object
#  4   Department          0 non-null      object
#  5   HomeToWork          0 non-null      float64
#  6   EducationField      0 non-null      object
#  7   Gender              0 non-null      object
#  8   HourlnWeek          0 non-null      float64
#  9   Involvement         0 non-null      int64
#  10  WorkLifeBalance     0 non-null      int64
#  11  Designation         0 non-null      object
#  12  JobSatisfaction     0 non-null      int64
#  13  ESOPs               0 non-null      int64
#  14  NumCompaniesWorked  0 non-null      int64
#  15  OverTime            0 non-null      int64
# ...

# %%
HrDataWoNa=HrData.dropna(how='all')
HrDataWoNa.head()
# Out:
#    EmployeeID  Attrition   Age TravelProfile Department  HomeToWork  \
# 0     5110001          0  35.0        Rarely  Analytics         5.0
# 1     5110002          1  32.0           Yes      Sales         5.0
# 2     5110003          0  31.0        Rarely  Analytics         5.0
# 3     5110004          0  34.0           Yes      Sales        10.0
# 4     5110005          0  37.0            No  Analytics        27.0
#
#   EducationField  Gender  HourlnWeek  Involvement  ...  JobSatisfaction ESOPs  \
# 0             CA    Male        69.0            1  ...                1     1
# 1     Statistics  Female        62.0            4  ...                2     0
# 2     Statistics       F        45.0            5  ...                2     1
# 3     Statistics  Female        32.0            3  ...                4     1
# 4     Statistics  Female        49.0            3  ...                4     1
#
#    NumCompaniesWorked  OverTime  SalaryHikelastYear  WorkExperience  \
# ...

# %%
HrDataWoNa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5180 entries, 0 to 5179
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   EmployeeID          5180 non-null   int64
#  1   Attrition           5180 non-null   int64
#  2   Age                 4864 non-null   float64
#  3   TravelProfile       5180 non-null   object
#  4   Department          5056 non-null   object
#  5   HomeToWork          4925 non-null   float64
#  6   EducationField      5180 non-null   object
#  7   Gender              5134 non-null   object
#  8   HourlnWeek          4893 non-null   float64
#  9   Involvement         5180 non-null   int64
#  10  WorkLifeBalance     5180 non-null   int64
#  11  Designation         5142 non-null   object
#  12  JobSatisfaction     5180 non-null   int64
#  13  ESOPs               5180 non-null   int64
#  14  NumCompaniesWorked  5180 non-null   int64
# ...

# %%
HrDataWoNa.columns[HrDataWoNa.isna().any()]
# Out:
# Index(['Age', 'Department', 'HomeToWork', 'Gender', 'HourlnWeek',
#        'Designation', 'SalaryHikelastYear', 'WorkExperience', 'LastPromotion',
#        'CurrentProfile', 'MonthlyIncome'],
#       dtype='object')

# %%
HrDataWoNa['HomeToWork'].unique()
# Out:
# array([  5.,  10.,  27.,  24.,   1.,   8.,   4.,  11.,  nan,  21.,   6.,
#         30.,  23.,   3.,   7.,  15.,  17.,  20.,  13.,  19.,  22.,  25.,
#         18.,   9.,  29.,  12.,  26.,  32.,  16.,  14.,   2.,  31.,  28.,
#        121.,  36.,  34.])

# %%
HrDataWoNa['HomeToWork'].median()
# Out:
# 9.0

# %%
HrDataWoNa['HomeToWork'].mean()
# Out:
# 11.10741116751269

# %%
plt.hist(HrDataWoNa['HomeToWork'])
# Out:
# (array([3.312e+03, 1.065e+03, 5.470e+02, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([  1.,  13.,  25.,  37.,  49.,  61.,  73.,  85.,  97., 109., 121.]),
#  <BarContainer object of 10 artists>)

# %%
sns.countplot(x=HrDataWoNa['HomeToWork'],data=HrDataWoNa)
# Out:
# <Axes: xlabel='HomeToWork', ylabel='count'>

# %%
sns.countplot(x=HrDataWoNa['HomeToWork'],data=HrDataWoNa,hue="Attrition")
# Out:
# <Axes: xlabel='HomeToWork', ylabel='count'>

# %%
HrDataWoNa.loc[HrDataWoNa['HomeToWork'].isna(),['HomeToWork']]
# Out:
#       HomeToWork
# 13           NaN
# 18           NaN
# 34           NaN
# 52           NaN
# 88           NaN
# ...          ...
# 5130         NaN
# 5144         NaN
# 5151         NaN
# 5152         NaN
# 5177         NaN
#
# [255 rows x 1 columns]

# %%
HrDataWoNa.loc[HrDataWoNa['HomeToWork'].isna(),['HomeToWork']]=HrDataWoNa['HomeToWork'].median()

# %%
HrDataWoNa['HomeToWork']
# Out:
# 0        5.0
# 1        5.0
# 2        5.0
# 3       10.0
# 4       27.0
#         ...
# 5175    13.0
# 5176     9.0
# 5177     9.0
# 5178    26.0
# 5179    13.0
# Name: HomeToWork, Length: 5180, dtype: float64

# %%
sns.countplot(x=HrDataWoNa['HomeToWork'],data=HrDataWoNa)
# Out:
# <Axes: xlabel='HomeToWork', ylabel='count'>

# %%
sns.countplot(x=HrDataWoNa['HomeToWork'],data=HrDataWoNa)
# Out:
# <Axes: xlabel='HomeToWork', ylabel='count'>

# %%
plt.hist(HrDataWoNa['HomeToWork'])
# Out:
# (array([3.567e+03, 1.065e+03, 5.470e+02, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([  1.,  13.,  25.,  37.,  49.,  61.,  73.,  85.,  97., 109., 121.]),
#  <BarContainer object of 10 artists>)

# %%
HrDataWoNa['Gender'].unique()
# Out:
# array(['Male', 'Female', 'F', nan], dtype=object)

# %%
HrDataWoNa.loc[HrDataWoNa['Gender']=='F',['Gender']]='Female'

# %%
HrDataWoNa['Gender'].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
HrDataWoNa.loc[HrDataWoNa['Gender'].isna(),['Gender']]='N'
HrDataWoNa.loc[HrDataWoNa['Gender']=='Female',['Gender']]='F'
HrDataWoNa.loc[HrDataWoNa['Gender']=='Male',['Gender']]='M'

# %%
HrDataWoNa['Gender'].unique()
# Out:
# array(['M', 'F', 'N'], dtype=object)

# %%
HrDataWoNa.describe()
# Out:
#          EmployeeID    Attrition          Age   HomeToWork   HourlnWeek  \
# count  5.180000e+03  5180.000000  4864.000000  5180.000000  4893.000000
# mean   5.112590e+06     0.278958    37.108553    11.003668    57.979767
# std    1.495482e+03     0.448530     9.248647     8.257384    12.996674
# min    5.110001e+06     0.000000    18.000000     1.000000    10.000000
# 25%    5.111296e+06     0.000000    30.000000     5.000000    49.000000
# 50%    5.112590e+06     0.000000    36.000000     9.000000    59.000000
# 75%    5.113885e+06     1.000000    43.000000    15.000000    67.000000
# max    5.115180e+06     1.000000    61.000000   121.000000    99.000000
#
#        Involvement  WorkLifeBalance  JobSatisfaction        ESOPs  \
# count  5180.000000      5180.000000      5180.000000  5180.000000
# mean      3.226641         3.012741         3.144402     0.490541
# std       0.872431         1.410602         1.342776     0.499959
# ...

# %%
plt.hist(HrDataWoNa['Age'])
# Out:
# (array([ 201.,  326.,  705., 1138.,  772.,  564.,  472.,  321.,  229.,
#          136.]),
#  array([18. , 22.3, 26.6, 30.9, 35.2, 39.5, 43.8, 48.1, 52.4, 56.7, 61. ]),
#  <BarContainer object of 10 artists>)

# %%
HrDataWoNa['Age'].mean()
# Out:
# 37.108552631578945

# %%
HrDataWoNa['Age'].median()
# Out:
# 36.0

# %%
sns.countplot(x='Age',data=HrDataWoNa)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
HrDataWoNa.loc[HrDataWoNa['Age'].isna(),['Age']]=HrDataWoNa['Age'].median()

# %%
plt.hist(HrDataWoNa['Age'])
# Out:
# (array([ 201.,  326.,  705., 1138., 1088.,  564.,  472.,  321.,  229.,
#          136.]),
#  array([18. , 22.3, 26.6, 30.9, 35.2, 39.5, 43.8, 48.1, 52.4, 56.7, 61. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.countplot(x='Age',data=HrDataWoNa)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
HrDataWoNa['Department'].value_counts()
# Out:
# Department
# Analytics    3219
# Sales        1615
# Marketing     222
# Name: count, dtype: int64

# %%
HrDataWoNa.loc[HrDataWoNa['Department'].isna()]
# Out:
#       EmployeeID  Attrition   Age TravelProfile Department  HomeToWork  \
# 81       5110082          0  38.0        Rarely        NaN         5.0
# 100      5110101          0  28.0        Rarely        NaN        11.0
# 120      5110121          0  32.0        Rarely        NaN         6.0
# 154      5110155          1  30.0        Rarely        NaN        10.0
# 209      5110210          1  18.0           Yes        NaN         4.0
# ...          ...        ...   ...           ...        ...         ...
# 4921     5114922          0  54.0        Rarely        NaN         9.0
# 4948     5114949          1  18.0           Yes        NaN         6.0
# 4997     5114998          0  18.0        Rarely        NaN        11.0
# 5005     5115006          0  34.0        Rarely        NaN         6.0
# 5045     5115046          0  30.0        Rarely        NaN        13.0
#
#          EducationField Gender  HourlnWeek  Involvement  ...  JobSatisfaction  \
# ...

# %%
HrDataWoNa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5180 entries, 0 to 5179
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   EmployeeID          5180 non-null   int64
#  1   Attrition           5180 non-null   int64
#  2   Age                 5180 non-null   float64
#  3   TravelProfile       5180 non-null   object
#  4   Department          5056 non-null   object
#  5   HomeToWork          5180 non-null   float64
#  6   EducationField      5180 non-null   object
#  7   Gender              5180 non-null   object
#  8   HourlnWeek          4893 non-null   float64
#  9   Involvement         5180 non-null   int64
#  10  WorkLifeBalance     5180 non-null   int64
#  11  Designation         5142 non-null   object
#  12  JobSatisfaction     5180 non-null   int64
#  13  ESOPs               5180 non-null   int64
#  14  NumCompaniesWorked  5180 non-null   int64
# ...

# %%
plt.hist(HrDataWoNa['MonthlyIncome'])
# Out:
# (array([1.000e+00, 2.329e+03, 2.272e+03, 4.840e+02, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([ 1000., 10400., 19800., 29200., 38600., 48000., 57400., 66800.,
#         76200., 85600., 95000.]),
#  <BarContainer object of 10 artists>)

# %%
HrDataWoNa['MonthlyIncome'].mean()
# Out:
# 21692.296441910752

# %%
HrDataWoNa['MonthlyIncome'].median()
# Out:
# 20160.0

# %%
HrDataWoNa.loc[HrDataWoNa['MonthlyIncome'].isna(),['MonthlyIncome']]=HrDataWoNa['MonthlyIncome'].mean()

# %%
plt.hist(HrDataWoNa['MonthlyIncome'])
# Out:
# (array([1.000e+00, 2.329e+03, 2.365e+03, 4.840e+02, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([ 1000., 10400., 19800., 29200., 38600., 48000., 57400., 66800.,
#         76200., 85600., 95000.]),
#  <BarContainer object of 10 artists>)

# %%
sns.countplot(x=HrDataWoNa['HourlnWeek'],data=HrDataWoNa,hue="Attrition")
# Out:
# <Axes: xlabel='HourlnWeek', ylabel='count'>

# %%
plt.hist(HrDataWoNa['HourlnWeek'])
# Out:
# (array([2.000e+00, 0.000e+00, 3.540e+02, 5.970e+02, 8.870e+02, 1.265e+03,
#         1.081e+03, 6.470e+02, 5.900e+01, 1.000e+00]),
#  array([10. , 18.9, 27.8, 36.7, 45.6, 54.5, 63.4, 72.3, 81.2, 90.1, 99. ]),
#  <BarContainer object of 10 artists>)

# %%
HrDataWoNa['HourlnWeek'].mean()
# Out:
# 57.979767014101775

# %%
HrDataWoNa['HourlnWeek'].median()
# Out:
# 59.0

# %%
HrDataWoNa.loc[HrDataWoNa['HourlnWeek'].isna(),['HourlnWeek']]=HrDataWoNa['HourlnWeek'].median()

# %%
HrDataWoNa['Designation'].unique()
# Out:
# array(['Executive', 'Manager', 'Senior Manager', 'AVP', 'VP', nan],
#       dtype=object)

# %%
sns.scatterplot(x=HrDataWoNa['Designation'],y=HrDataWoNa['MonthlyIncome'])
# Out:
# <Axes: xlabel='Designation', ylabel='MonthlyIncome'>

# %%
HrDataWoNa.groupby('Designation')['SalaryHikelastYear'].min()
# Out:
# Designation
# AVP               16.0
# Executive         16.0
# Manager           16.0
# Senior Manager    16.0
# VP                16.0
# Name: SalaryHikelastYear, dtype: float64

# %%
HrDataWoNa.groupby('Designation')['SalaryHikelastYear'].max()
# Out:
# Designation
# AVP               31.0
# Executive         31.0
# Manager           31.0
# Senior Manager    31.0
# VP                30.0
# Name: SalaryHikelastYear, dtype: float64

# %%
HrDataWoNa.groupby('Designation')['SalaryHikelastYear'].mean()
# Out:
# Designation
# AVP               20.639144
# Executive         20.772683
# Manager           20.670644
# Senior Manager    20.457778
# VP                19.775785
# Name: SalaryHikelastYear, dtype: float64

# %%
HrDataWoNa.groupby('Designation')['SalaryHikelastYear'].median()
# Out:
# Designation
# AVP               19.0
# Executive         20.0
# Manager           20.0
# Senior Manager    19.0
# VP                19.0
# Name: SalaryHikelastYear, dtype: float64

# %%
desIncome=HrDataWoNa.loc[HrDataWoNa['SalaryHikelastYear'].isna()]
sns.scatterplot(x=desIncome['Designation'],y=desIncome['MonthlyIncome'])
# Out:
# <Axes: xlabel='Designation', ylabel='MonthlyIncome'>

# %%
sns.countplot(x=desIncome['MonthlyIncome'],data=desIncome)
# Out:
# <Axes: xlabel='MonthlyIncome', ylabel='count'>

# %%
desIncome.groupby('Designation')['MonthlyIncome'].mean()
# Out:
# Designation
# AVP               22799.000000
# Manager           22832.118528
# Senior Manager    23281.079545
# Name: MonthlyIncome, dtype: float64

# %%
HrDataWoNa.groupby('Designation')['MonthlyIncome'].mean()
# Out:
# Designation
# AVP               30602.469741
# Executive         18278.584141
# Manager           20938.740828
# Senior Manager    25258.900347
# VP                34599.503571
# Name: MonthlyIncome, dtype: float64

# %%
HrDataWoNa.loc[HrDataWoNa['SalaryHikelastYear'].isna(),['SalaryHikelastYear']]=19.0

# %%
HrDataWoNa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5180 entries, 0 to 5179
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   EmployeeID          5180 non-null   int64
#  1   Attrition           5180 non-null   int64
#  2   Age                 5180 non-null   float64
#  3   TravelProfile       5180 non-null   object
#  4   Department          5056 non-null   object
#  5   HomeToWork          5180 non-null   float64
#  6   EducationField      5180 non-null   object
#  7   Gender              5180 non-null   object
#  8   HourlnWeek          5180 non-null   float64
#  9   Involvement         5180 non-null   int64
#  10  WorkLifeBalance     5180 non-null   int64
#  11  Designation         5142 non-null   object
#  12  JobSatisfaction     5180 non-null   int64
#  13  ESOPs               5180 non-null   int64
#  14  NumCompaniesWorked  5180 non-null   int64
# ...

# %%
sns.histplot(x=HrDataWoNa['SalaryHikelastYear'],data=HrDataWoNa)
# Out:
# <Axes: xlabel='SalaryHikelastYear', ylabel='Count'>

# %%
HrDataWoNa.loc[HrDataWoNa['WorkExperience'].isna()]
# Out:
#       EmployeeID  Attrition   Age TravelProfile Department  HomeToWork  \
# 46       5110047          1  34.0           Yes  Analytics         8.0
# 84       5110085          0  27.0            No      Sales         1.0
# 86       5110087          1  31.0        Rarely      Sales         7.0
# 115      5110116          0  32.0        Rarely  Analytics         1.0
# 118      5110119          0  30.0        Rarely      Sales         6.0
# ...          ...        ...   ...           ...        ...         ...
# 5095     5115096          0  26.0           Yes  Analytics         1.0
# 5112     5115113          1  31.0        Rarely  Analytics        23.0
# 5133     5115134          0  38.0        Rarely  Analytics        30.0
# 5143     5115144          0  37.0        Rarely  Analytics        29.0
# 5146     5115147          0  40.0        Rarely  Analytics        12.0
#
#          EducationField Gender  HourlnWeek  Involvement  ...  JobSatisfaction  \
# ...

# %%
sns.scatterplot(y=HrDataWoNa['WorkExperience'],x=HrDataWoNa['MonthlyIncome'])
# Out:
# <Axes: xlabel='MonthlyIncome', ylabel='WorkExperience'>

# %%
sns.scatterplot(y=HrDataWoNa['WorkExperience'],x=HrDataWoNa['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='WorkExperience'>

# %%
HrDataWoNa_test=HrDataWoNa.loc[HrDataWoNa['WorkExperience'].isna(),['Age']]

# %%
HrDataWoNa_test
# Out:
#        Age
# 46    34.0
# 84    27.0
# 86    31.0
# 115   32.0
# 118   30.0
# ...    ...
# 5095  26.0
# 5112  31.0
# 5133  38.0
# 5143  37.0
# 5146  40.0
#
# [187 rows x 1 columns]

# %%
AgeExp=HrDataWoNa.groupby('Age')['WorkExperience'].mean().reset_index()

# %%
HrDataWoNa_test_merge=HrDataWoNa_test.merge(AgeExp,how='left',on='Age')

# %%
HrDataWoNa_test_merge
# Out:
#       Age  WorkExperience
# 0    34.0        9.320197
# 1    27.0        5.992188
# 2    31.0        7.960976
# 3    32.0        8.252294
# 4    30.0        8.151042
# ..    ...             ...
# 182  26.0        6.153153
# 183  31.0        7.960976
# 184  38.0       11.903409
# 185  37.0       12.074866
# 186  40.0       14.156463
#
# [187 rows x 2 columns]

# %%
HrDataWoNa.loc[HrDataWoNa['WorkExperience'].isna(),['WorkExperience']]=HrDataWoNa_test_merge.loc[HrDataWoNa_test_merge['Age'].isin(HrDataWoNa['Age']),['WorkExperience']].values

# %%
HrDataWoNa.loc[HrDataWoNa['WorkExperience'].isna()]
# Out:
# Empty DataFrame
# Columns: [EmployeeID, Attrition, Age, TravelProfile, Department, HomeToWork, EducationField, Gender, HourlnWeek, Involvement, WorkLifeBalance, Designation, JobSatisfaction, ESOPs, NumCompaniesWorked, OverTime, SalaryHikelastYear, WorkExperience, LastPromotion, CurrentProfile, MaritalStatus, MonthlyIncome]
# Index: []
#
# [0 rows x 22 columns]

# %%
HrDataWoNa_test_merge.loc[HrDataWoNa_test_merge['Age'].isin(HrDataWoNa['Age']),['WorkExperience','Age']]
# Out:
#      WorkExperience   Age
# 0          9.320197  34.0
# 1          5.992188  27.0
# 2          7.960976  31.0
# 3          8.252294  32.0
# 4          8.151042  30.0
# ..              ...   ...
# 182        6.153153  26.0
# 183        7.960976  31.0
# 184       11.903409  38.0
# 185       12.074866  37.0
# 186       14.156463  40.0
#
# [187 rows x 2 columns]

# %%
HrDataWoNa_test_merge.loc[HrDataWoNa_test_merge.duplicated(keep=False)].sort_values('Age')
# Out:
#       Age  WorkExperience
# 140  25.0        5.073684
# 113  25.0        5.073684
# 97   25.0        5.073684
# 128  25.0        5.073684
# 19   26.0        6.153153
# ..    ...             ...
# 90   51.0       19.688312
# 20   56.0       23.895833
# 160  56.0       23.895833
# 12   56.0       23.895833
# 8    56.0       23.895833
#
# [180 rows x 2 columns]

# %%
HrDataWoNa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5180 entries, 0 to 5179
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   EmployeeID          5180 non-null   int64
#  1   Attrition           5180 non-null   int64
#  2   Age                 5180 non-null   float64
#  3   TravelProfile       5180 non-null   object
#  4   Department          5056 non-null   object
#  5   HomeToWork          5180 non-null   float64
#  6   EducationField      5180 non-null   object
#  7   Gender              5180 non-null   object
#  8   HourlnWeek          5180 non-null   float64
#  9   Involvement         5180 non-null   int64
#  10  WorkLifeBalance     5180 non-null   int64
#  11  Designation         5142 non-null   object
#  12  JobSatisfaction     5180 non-null   int64
#  13  ESOPs               5180 non-null   int64
#  14  NumCompaniesWorked  5180 non-null   int64
# ...

# %%
HrDataWoNa['LastPromotion'].unique()
# Out:
# array([ 2.,  1.,  0.,  3.,  5.,  8.,  6.,  4.,  7.,  9., nan, 11., 12.,
#        10., 15., 16., 13., 14.])

# %%
sns.countplot(x=HrDataWoNa['LastPromotion'],data=HrDataWoNa)
# Out:
# <Axes: xlabel='LastPromotion', ylabel='count'>

# %%
HrDataWoNa.loc[HrDataWoNa['LastPromotion'].isna(),['LastPromotion']]=0

# %%
sns.countplot(x=HrDataWoNa['LastPromotion'],data=HrDataWoNa)
# Out:
# <Axes: xlabel='LastPromotion', ylabel='count'>

# %%
HrDataWoNa['CurrentProfile'].unique()
# Out:
# array([nan,  3.,  9.,  2.,  8.,  4.,  0.,  7., 10.,  1., 11.,  5., 13.,
#         6., 12., 18., 15., 17., 14., 16.])

# %%
sns.countplot(x=HrDataWoNa['CurrentProfile'],data=HrDataWoNa)
# Out:
# <Axes: xlabel='CurrentProfile', ylabel='count'>

# %%
plt.plot(HrDataWoNa['CurrentProfile'],HrDataWoNa['LastPromotion'])

# %%
sns.scatterplot(x=HrDataWoNa['CurrentProfile'],y=HrDataWoNa['LastPromotion'])
# Out:
# <Axes: xlabel='CurrentProfile', ylabel='LastPromotion'>

# %%
sns.scatterplot(x=HrDataWoNa['CurrentProfile'],y=HrDataWoNa['WorkExperience'])
# Out:
# <Axes: xlabel='CurrentProfile', ylabel='WorkExperience'>

# %%
sns.countplot(x=HrDataWoNa['CurrentProfile'],data=HrDataWoNa,hue=HrDataWoNa['Gender'])
# Out:
# <Axes: xlabel='CurrentProfile', ylabel='count'>

# %%
sns.countplot(x=HrDataWoNa['CurrentProfile'],data=HrDataWoNa,hue=HrDataWoNa['Designation'])
# Out:
# <Axes: xlabel='CurrentProfile', ylabel='count'>

# %%
plt.hist(HrDataWoNa['CurrentProfile'])
# Out:
# (array([1168., 1450.,  563.,  524.,  490.,  403.,  145.,   82.,   25.,
#           19.]),
#  array([ 0. ,  1.8,  3.6,  5.4,  7.2,  9. , 10.8, 12.6, 14.4, 16.2, 18. ]),
#  <BarContainer object of 10 artists>)

# %%
HrDataWoNa['CurrentProfile'].median()
# Out:
# 3.0

# %%
HrDataWoNa.loc[HrDataWoNa['CurrentProfile'].isna(),['CurrentProfile']]=2.5

# %%
plt.hist(HrDataWoNa['CurrentProfile'])
# Out:
# (array([1168., 1761.,  563.,  524.,  490.,  403.,  145.,   82.,   25.,
#           19.]),
#  array([ 0. ,  1.8,  3.6,  5.4,  7.2,  9. , 10.8, 12.6, 14.4, 16.2, 18. ]),
#  <BarContainer object of 10 artists>)

# %%
HrDataWoNa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5180 entries, 0 to 5179
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   EmployeeID          5180 non-null   int64
#  1   Attrition           5180 non-null   int64
#  2   Age                 5180 non-null   float64
#  3   TravelProfile       5180 non-null   object
#  4   Department          5056 non-null   object
#  5   HomeToWork          5180 non-null   float64
#  6   EducationField      5180 non-null   object
#  7   Gender              5180 non-null   object
#  8   HourlnWeek          5180 non-null   float64
#  9   Involvement         5180 non-null   int64
#  10  WorkLifeBalance     5180 non-null   int64
#  11  Designation         5142 non-null   object
#  12  JobSatisfaction     5180 non-null   int64
#  13  ESOPs               5180 non-null   int64
#  14  NumCompaniesWorked  5180 non-null   int64
# ...

# %%
HrDataWoNa['Designation'].isna().value_counts()
# Out:
# Designation
# False    5142
# True       38
# Name: count, dtype: int64

# %%
HrDataWoNa['Designation'].unique()
# Out:
# array(['Executive', 'Manager', 'Senior Manager', 'AVP', 'VP', nan],
#       dtype=object)

# %%
HrDataWoNa.loc[HrDataWoNa['Designation'].isna(),['Designation']]='Unknown'

# %%
HrDataWoNa['Designation'].unique()
# Out:
# array(['Executive', 'Manager', 'Senior Manager', 'AVP', 'VP', 'Unknown'],
#       dtype=object)

# %%
HrDataWoNa['Department'].isna().value_counts()
# Out:
# Department
# False    5056
# True      124
# Name: count, dtype: int64

# %%
HrDataWoNa['Department'].unique()
# Out:
# array(['Analytics', 'Sales', 'Marketing', nan], dtype=object)

# %%
HrDataWoNa.loc[HrDataWoNa['Department'].isna(),['Department']]='Unknown'

# %%
HrDataWoNa['Department'].unique()
# Out:
# array(['Analytics', 'Sales', 'Marketing', 'Unknown'], dtype=object)

# %%
HrDataWoNa.to_csv("HR_Clean_Dataset.csv", index = False)

# %%
HrDataWoNa['MaritalStatus'].unique()
# Out:
# array(['M', 'Single', 'Divorsed', 'Married'], dtype=object)

# %%
HrDataWoNa.loc[HrDataWoNa['MaritalStatus']=='M',['MaritalStatus']]='Married'
HrDataWoNa['MaritalStatus'].unique()
# Out:
# array(['Married', 'Single', 'Divorsed'], dtype=object)

# %%
HRdata = pd.get_dummies(HrDataWoNa)
HRdata = HRdata.astype(int)

# %%
HRdata
# Out:
#       EmployeeID  Attrition  Age  HomeToWork  HourlnWeek  Involvement  \
# 0        5110001          0   35           5          69            1
# 1        5110002          1   32           5          62            4
# 2        5110003          0   31           5          45            5
# 3        5110004          0   34          10          32            3
# 4        5110005          0   37          27          49            3
# ...          ...        ...  ...         ...         ...          ...
# 5175     5115176          0   36          13          53            3
# 5176     5115177          0   36           9          66            1
# 5177     5115178          0   29           9          62            4
# 5178     5115179          0   26          26          61            3
# 5179     5115180          1   36          13          74            4
#
#       WorkLifeBalance  JobSatisfaction  ESOPs  NumCompaniesWorked  ...  \
# ...

# %%
HRdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5180 entries, 0 to 5179
# Data columns (total 41 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   EmployeeID                        5180 non-null   int32
#  1   Attrition                         5180 non-null   int32
#  2   Age                               5180 non-null   int32
#  3   HomeToWork                        5180 non-null   int32
#  4   HourlnWeek                        5180 non-null   int32
#  5   Involvement                       5180 non-null   int32
#  6   WorkLifeBalance                   5180 non-null   int32
#  7   JobSatisfaction                   5180 non-null   int32
#  8   ESOPs                             5180 non-null   int32
#  9   NumCompaniesWorked                5180 non-null   int32
#  10  OverTime                          5180 non-null   int32
#  11  SalaryHikelastYear                5180 non-null   int32
# ...

# %%
HRdata.drop(['TravelProfile_No','Department_Unknown','EducationField_Other','Gender_N','Designation_Unknown','MaritalStatus_Divorsed'],axis=1,inplace=True)

# %%
HRdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5180 entries, 0 to 5179
# Data columns (total 35 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   EmployeeID                        5180 non-null   int32
#  1   Attrition                         5180 non-null   int32
#  2   Age                               5180 non-null   int32
#  3   HomeToWork                        5180 non-null   int32
#  4   HourlnWeek                        5180 non-null   int32
#  5   Involvement                       5180 non-null   int32
#  6   WorkLifeBalance                   5180 non-null   int32
#  7   JobSatisfaction                   5180 non-null   int32
#  8   ESOPs                             5180 non-null   int32
#  9   NumCompaniesWorked                5180 non-null   int32
#  10  OverTime                          5180 non-null   int32
#  11  SalaryHikelastYear                5180 non-null   int32
# ...

# %%
HRdata.corr()
# Out:
#                                   EmployeeID  Attrition       Age  HomeToWork  \
# EmployeeID                          1.000000  -0.023067  0.021768   -0.017402
# Attrition                          -0.023067   1.000000 -0.180490    0.086266
# Age                                 0.021768  -0.180490  1.000000    0.014027
# HomeToWork                         -0.017402   0.086266  0.014027    1.000000
# HourlnWeek                          0.011007   0.021145 -0.009194    0.055837
# Involvement                         0.002321   0.144332 -0.023155   -0.003144
# WorkLifeBalance                    -0.003441   0.013608 -0.012026    0.019905
# JobSatisfaction                    -0.004581   0.126745 -0.016401    0.009931
# ESOPs                               0.009884   0.012200 -0.013094    0.007609
# NumCompaniesWorked                 -0.000951   0.049829  0.300425   -0.010731
# OverTime                           -0.009149   0.281113  0.007451    0.048184
# ...

# %%
plt.figure(figsize=(20, 16))
sns.heatmap(HRdata.corr(),annot=True, fmt=".1f")
plt.show()

# %%
# Dropping WorkExperience as it is highly correlated with Age and Monthly Income, 
# Dropping EducationField_MBA as it is highly correlated with Department_Marketing	
HRdata.drop(['WorkExperience','EducationField_MBA'],axis=1,inplace=True)

# %%
HRdata.head()
# Out:
#    EmployeeID  Attrition  Age  HomeToWork  HourlnWeek  Involvement  \
# 0     5110001          0   35           5          69            1
# 1     5110002          1   32           5          62            4
# 2     5110003          0   31           5          45            5
# 3     5110004          0   34          10          32            3
# 4     5110005          0   37          27          49            3
#
#    WorkLifeBalance  JobSatisfaction  ESOPs  NumCompaniesWorked  ...  \
# 0                1                1      1                   1  ...
# 1                3                2      0                   8  ...
# 2                3                2      1                   3  ...
# 3                2                4      1                   1  ...
# 4                4                4      1                   8  ...
#
#    EducationField_Statistics  Gender_F  Gender_M  Designation_AVP  \
# 0                          0         0         1                0
# ...

# %%
HRdata.to_csv("CleanDataset.csv", index = False)
