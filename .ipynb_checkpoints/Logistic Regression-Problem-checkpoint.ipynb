# %%
import pandas as pd
import numpy as np
import math
import seaborn as sns
from numpy.linalg import inv
from sklearn.model_selection import train_test_split
from scipy.stats import multivariate_normal
from sklearn.metrics import f1_score, confusion_matrix
from sklearn.utils.multiclass import unique_labels
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv(r"C:\Users\cks12\Downloads\PML Project\dataset\raw\CleanDataset.csv")

# %%
X=df[['Age','WorkExperience','MonthlyIncome']]

# %%
y=df['Attrition']

# %%
Xtrain, Xtest, ytrain, ytest = train_test_split(X, y)

# %%
prior_mean = np.zeros(Xtrain.shape[1]) #p_m

# %%
prior_mean
# Out:
# array([0., 0., 0.])

# %%
lam = 1
prior_variance = np.eye(Xtrain.shape[1])/lam

# %%
prior_variance
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
w_init1 =[-8.12,34,8.12]
#p = 1/(1+np.exp(-Xtrain.dot(w_init1)))

# %%
#np.sum((ytrain*np.log1p(p)+(1-ytrain)*np.log1p(1-p)))
def softplus(x):
    return np.log1p(np.exp(-np.abs(x))) + np.maximum(x, 0)
z = Xtrain.dot(w_init1)
-np.sum(ytrain * softplus(-z) + (1 - ytrain) * softplus(z))
# Out:
# -506602950.1119604

# %%
def logJointLikelihood(X, t, w, p_m, p_v):

    #p = 1/(1+np.exp(-X.dot(w)))
    #loglikelihood =  np.sum((t*np.log1p(p)+(1-t)*np.log1p(1-p)))
    z=X.dot(w)
    loglikelihood = -np.sum(t * softplus(-z) + (1 - t) * softplus(z))
    logPrior = np.log(multivariate_normal.pdf(w, p_m, p_v))
    
    logJointLikelihood = (loglikelihood + logPrior)
    
    NeglogJointLikelihood= -1*logJointLikelihood

    return NeglogJointLikelihood

# %%
def logJointLikelihood_grad(X, t, w, p_m, p_v):

 
    p = 1/(1 + np.exp(-X.dot(w)))
    
    
    grad = X.T.dot(p-t)+ inv(p_v).dot(w-p_m)  

    return grad

# %%
def logJointLikelihood_hess(X, t, w, p_m, p_v):

   
    p = 1/(1 + np.exp(-X.dot(w)))
    
    hess = (( X.T*(p*(1-p)))).dot(X)+inv(p_v)

    return hess

# %%
def GradientDescent(X, t, w, p_m, p_v, eta, tol, max_iter):

    log_joint_likelihood = 1e5
    log_joint_likelihoods = []
    w_history=[]
    w_history.append(w)
    w_opt = 0

    for i in range(max_iter):
        


        grad = logJointLikelihood_grad(X, t, w, p_m, p_v)
        print(grad)

        # update the coefficient for next step
        w_new =  w - eta* grad  #fill in
        w_history.append(w_new)

        # check convergence
        log_joint_likelihood_new = logJointLikelihood(X, t, w_new, p_m, p_v)
        print(log_joint_likelihood_new)
        if (abs(log_joint_likelihood_new - log_joint_likelihood) < tol):
            break
        else:
            log_joint_likelihoods.append(log_joint_likelihood_new)
            log_joint_likelihood, w = log_joint_likelihood_new, w_new
            

    w_opt = w_new
    return w_opt, np.array(log_joint_likelihoods), w_history

# %%
def NewtonRaphson(X, t, w, p_m, p_v, eta, tol, max_iter):

    # hyper-parameters setting (Note: 'loss' is set to large value to avoid first time stop)
    log_joint_likelihood = 1e5
    log_joint_likelihoods = []
    w_opt = 0
    w_history= []
    w_history.append(w)

    for i in range(max_iter):

        # find the next step length.
        grad = logJointLikelihood_grad(X, t, w, p_m, p_v)
        
        hess = logJointLikelihood_hess(X, t, w, p_m, p_v)
        

        # update the coefficient for next step
        w_new =   w-eta*(inv(hess)*grad)
        w_history.append(w_new)

        # check convergence
        log_joint_likelihood_new = logJointLikelihood(X, t, w_new, p_m, p_v)
        if (abs(log_joint_likelihood_new - log_joint_likelihood) < tol):
            break
        else:
            log_joint_likelihoods.append(log_joint_likelihood_new)
            log_joint_likelihood, w = log_joint_likelihood_new, w_new
            

        w_opt = w_new

    return w_opt, log_joint_likelihoods, w_history

# %%
class BayesianLogistic(object):



    def __init__(self, p_m, p_v, solver, eta=1e-4, tol=1e-5, max_iter=100):


        self.p_m = p_m
        self.p_v = p_v
        self.solver = solver
        self.eta = eta
        self.tol = tol
        self.max_iter = max_iter


    def fit(self, X, t):

        w_init = 1e-5*np.ones(X.shape[1])

        if (self.solver == 'gd'):
            self.coef_, self.log_joint_likelihood_, self.weight_history_ = GradientDescent(X, t, w_init, self.p_m, self.p_v, self.eta, self.tol, self.max_iter)
            print(self.log_joint_likelihood_)
        else:
            self.coef_, self.log_joint_likelihood_, self.weight_history_ = NewtonRaphson(X, t, w_init, self.p_m, self.p_v, self.eta, self.tol, self.max_iter)

        return self


    def predict(self, X):


        pred = []

        for p in 1/(1+np.exp(-X.dot(self.coef_))):
            if p <= 0.4:
                pred.append(0)
            else:
                pred.append(1)

        return np.array(pred)

# %%
model = BayesianLogistic(p_m=prior_mean, p_v=prior_variance, solver='gd', eta=1e-4, max_iter=50) #try changing eta and max_iter for better convergence
model.fit(Xtrain, ytrain)
# Out:
# Age               4.265743e+04
# WorkExperience    1.509686e+04
# MonthlyIncome     2.505659e+07
# dtype: float64
# inf
# Age              -3.724127e+04
# WorkExperience   -8.986469e+03
# MonthlyIncome    -2.172763e+07
# dtype: float64
# inf
# Age              -3.723754e+04
# WorkExperience   -8.985570e+03
# MonthlyIncome    -2.172545e+07
# dtype: float64
# inf
# Age               1.066302e+05
# WorkExperience    3.401948e+04
# MonthlyIncome     6.235555e+07
# dtype: float64
# inf
# Age              -3.724448e+04
# WorkExperience   -8.988074e+03
# MonthlyIncome    -2.172952e+07
# dtype: float64
# inf
# Age              -3.724076e+04
# WorkExperience   -8.987175e+03
# MonthlyIncome    -2.172734e+07
# dtype: float64
# inf
# Age              -3.723703e+04
# WorkExperience   -8.986276e+03
# MonthlyIncome    -2.172517e+07
# dtype: float64
# inf
# Age               1.066307e+05
# WorkExperience    3.401878e+04
# MonthlyIncome     6.235583e+07
# dtype: float64
# inf
# Age              -3.724397e+04
# WorkExperience   -8.988779e+03
# MonthlyIncome    -2.172924e+07
# dtype: float64
# inf
# Age              -3.724025e+04
# WorkExperience   -8.987881e+03
# MonthlyIncome    -2.172706e+07
# dtype: float64
# inf
# Age               1.066275e+05
# WorkExperience    3.401717e+04
# MonthlyIncome     6.235394e+07
# dtype: float64
# inf
# Age              -3.724719e+04
# WorkExperience   -8.990383e+03
# MonthlyIncome    -2.173113e+07
# dtype: float64
# inf
# Age              -3.724346e+04
# WorkExperience   -8.989484e+03
# MonthlyIncome    -2.172895e+07
# dtype: float64
# inf
# Age              -3.723974e+04
# WorkExperience   -8.988585e+03
# MonthlyIncome    -2.172678e+07
# dtype: float64
# inf
# Age               1.066280e+05
# WorkExperience    3.401647e+04
# MonthlyIncome     6.235422e+07
# dtype: float64
# inf
# Age              -3.724668e+04
# WorkExperience   -8.991088e+03
# MonthlyIncome    -2.173084e+07
# dtype: float64
# inf
# Age              -3.724295e+04
# WorkExperience   -8.990189e+03
# MonthlyIncome    -2.172867e+07
# dtype: float64
# inf
# Age              -3.723923e+04
# WorkExperience   -8.989290e+03
# MonthlyIncome    -2.172650e+07
# dtype: float64
# inf
# Age               1.066285e+05
# WorkExperience    3.401576e+04
# MonthlyIncome     6.235451e+07
# dtype: float64
# inf
# Age              -3.724617e+04
# WorkExperience   -8.991793e+03
# MonthlyIncome    -2.173056e+07
# dtype: float64
# inf
# Age              -3.724244e+04
# WorkExperience   -8.990894e+03
# MonthlyIncome    -2.172839e+07
# dtype: float64
# inf
# Age              -3.723872e+04
# WorkExperience   -8.989994e+03
# MonthlyIncome    -2.172621e+07
# dtype: float64
# inf
# Age               1.066290e+05
# WorkExperience    3.401506e+04
# MonthlyIncome     6.235479e+07
# dtype: float64
# inf
# Age              -3.724566e+04
# WorkExperience   -8.992497e+03
# MonthlyIncome    -2.173028e+07
# dtype: float64
# inf
# Age              -3.724193e+04
# WorkExperience   -8.991598e+03
# MonthlyIncome    -2.172810e+07
# dtype: float64
# inf
# Age              -3.723821e+04
# WorkExperience   -8.990699e+03
# MonthlyIncome    -2.172593e+07
# dtype: float64
# inf
# Age               1.066295e+05
# WorkExperience    3.401435e+04
# MonthlyIncome     6.235507e+07
# dtype: float64
# inf
# Age              -3.724515e+04
# WorkExperience   -8.993201e+03
# MonthlyIncome    -2.172999e+07
# dtype: float64
# inf
# Age              -3.724142e+04
# WorkExperience   -8.992302e+03
# MonthlyIncome    -2.172782e+07
# dtype: float64
# inf
# Age              -3.723770e+04
# WorkExperience   -8.991402e+03
# MonthlyIncome    -2.172565e+07
# dtype: float64
# inf
# Age               1.066300e+05
# WorkExperience    3.401365e+04
# MonthlyIncome     6.235536e+07
# dtype: float64
# inf
# Age              -3.724464e+04
# WorkExperience   -8.993905e+03
# MonthlyIncome    -2.172971e+07
# dtype: float64
# inf
# Age              -3.724091e+04
# WorkExperience   -8.993005e+03
# MonthlyIncome    -2.172754e+07
# dtype: float64
# inf
# Age              -3.723719e+04
# WorkExperience   -8.992106e+03
# MonthlyIncome    -2.172536e+07
# dtype: float64
# inf
# Age               1.066305e+05
# WorkExperience    3.401295e+04
# MonthlyIncome     6.235564e+07
# dtype: float64
# inf
# Age              -3.724413e+04
# WorkExperience   -8.994608e+03
# MonthlyIncome    -2.172943e+07
# dtype: float64
# inf
# Age              -3.724040e+04
# WorkExperience   -8.993709e+03
# MonthlyIncome    -2.172725e+07
# dtype: float64
# inf
# Age               1.066273e+05
# WorkExperience    3.401135e+04
# MonthlyIncome     6.235375e+07
# dtype: float64
# inf
# Age              -3.724734e+04
# WorkExperience   -8.996210e+03
# MonthlyIncome    -2.173132e+07
# dtype: float64
# inf
# Age              -3.724362e+04
# WorkExperience   -8.995311e+03
# MonthlyIncome    -2.172914e+07
# dtype: float64
# inf
# Age              -3.723989e+04
# WorkExperience   -8.994411e+03
# MonthlyIncome    -2.172697e+07
# dtype: float64
# inf
# Age               1.066278e+05
# WorkExperience    3.401064e+04
# MonthlyIncome     6.235403e+07
# dtype: float64
# inf
# Age              -3.724683e+04
# WorkExperience   -8.996913e+03
# MonthlyIncome    -2.173103e+07
# dtype: float64
# inf
# Age              -3.724311e+04
# WorkExperience   -8.996013e+03
# MonthlyIncome    -2.172886e+07
# dtype: float64
# inf
# Age              -3.723938e+04
# WorkExperience   -8.995114e+03
# MonthlyIncome    -2.172669e+07
# dtype: float64
# inf
# Age               1.066283e+05
# WorkExperience    3.400994e+04
# MonthlyIncome     6.235432e+07
# dtype: float64
# inf
# Age              -3.724632e+04
# WorkExperience   -8.997615e+03
# MonthlyIncome    -2.173075e+07
# dtype: float64
# inf
# Age              -3.724260e+04
# WorkExperience   -8.996715e+03
# MonthlyIncome    -2.172858e+07
# dtype: float64
# inf
# Age              -3.723887e+04
# WorkExperience   -8.995816e+03
# MonthlyIncome    -2.172640e+07
# dtype: float64
# inf
# Age               1.066289e+05
# WorkExperience    3.400924e+04
# MonthlyIncome     6.235460e+07
# dtype: float64
# inf
# [inf inf inf inf inf inf inf inf inf inf inf inf inf inf inf inf inf inf
#  inf inf inf inf inf inf inf inf inf inf inf inf inf inf inf inf inf inf
#  inf inf inf inf inf inf inf inf inf inf inf inf inf inf]

# %%
model.coef_
# Out:
# Age                 -8.811644
# WorkExperience     -13.357653
# MonthlyIncome    -5345.194770
# dtype: float64

# %%
model.log_joint_likelihood_
# Out:
# array([inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf,
#        inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf,
#        inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf,
#        inf, inf, inf, inf, inf, inf, inf, inf, inf, inf, inf])

# %%
model.weight_history_
# Out:
# [array([1.e-05, 1.e-05, 1.e-05]),
#  Age                 -4.265733
#  WorkExperience      -1.509676
#  MonthlyIncome    -2505.658930
#  dtype: float64,
#  Age                -0.541607
#  WorkExperience     -0.611029
#  MonthlyIncome    -332.896160
#  dtype: float64,
#  Age                  3.182148
#  WorkExperience       0.287528
#  MonthlyIncome     1839.649334
#  dtype: float64,
#  Age                 -7.480871
#  WorkExperience      -3.114420
#  MonthlyIncome    -4395.905428
#  dtype: float64,
#  Age                 -3.756422
#  WorkExperience      -2.215613
#  MonthlyIncome    -2222.953633
#  dtype: float64,
#  Age               -0.032347
#  WorkExperience    -1.316896
#  MonthlyIncome    -50.219133
#  dtype: float64,
#  Age                  3.691356
#  WorkExperience      -0.418268
#  MonthlyIncome     2122.298093
#  dtype: float64,
#  Age                 -6.971713
#  WorkExperience      -3.820146
#  MonthlyIncome    -4113.284934
#  dtype: float64,
#  Age                 -3.247316
#  WorkExperience      -2.921268
#  MonthlyIncome    -1940.361401
#  dtype: float64,
#  Age                 0.476709
#  WorkExperience     -2.022480
#  MonthlyIncome     232.344839
#  dtype: float64,
#  Age                -10.186039
#  WorkExperience      -5.424197
#  MonthlyIncome    -6003.049192
#  dtype: float64,
#  Age                 -6.461320
#  WorkExperience      -4.525159
#  MonthlyIncome    -3829.936683
#  dtype: float64,
#  Age                 -2.736974
#  WorkExperience      -3.626210
#  MonthlyIncome    -1657.041485
#  dtype: float64,
#  Age                 0.987000
#  WorkExperience     -2.727352
#  MonthlyIncome     515.636424
#  dtype: float64,
#  Age                 -9.675799
#  WorkExperience      -6.128998
#  MonthlyIncome    -5719.785937
#  dtype: float64,
#  Age                 -5.951131
#  WorkExperience      -5.229890
#  MonthlyIncome    -3546.701754
#  dtype: float64,
#  Age                 -2.226836
#  WorkExperience      -4.330871
#  MonthlyIncome    -1373.834880
#  dtype: float64,
#  Age                 1.497087
#  WorkExperience     -3.431942
#  MonthlyIncome     798.814708
#  dtype: float64,
#  Age                 -9.165763
#  WorkExperience      -6.833518
#  MonthlyIncome    -5436.635970
#  dtype: float64,
#  Age                 -5.441147
#  WorkExperience      -5.934339
#  MonthlyIncome    -3263.580102
#  dtype: float64,
#  Age                 -1.716902
#  WorkExperience      -5.035249
#  MonthlyIncome    -1090.741540
#  dtype: float64,
#  Age                  2.006969
#  WorkExperience      -4.136250
#  MonthlyIncome     1081.879738
#  dtype: float64,
#  Age                 -8.655931
#  WorkExperience      -7.537756
#  MonthlyIncome    -5153.599247
#  dtype: float64,
#  Age                 -4.931366
#  WorkExperience      -6.638506
#  MonthlyIncome    -2980.571682
#  dtype: float64,
#  Age                -1.207173
#  WorkExperience     -5.739346
#  MonthlyIncome    -807.761421
#  dtype: float64,
#  Age                  2.516648
#  WorkExperience      -4.840276
#  MonthlyIncome     1364.831559
#  dtype: float64,
#  Age                 -8.146304
#  WorkExperience      -8.241712
#  MonthlyIncome    -4870.675721
#  dtype: float64,
#  Age                 -4.421789
#  WorkExperience      -7.342392
#  MonthlyIncome    -2697.676449
#  dtype: float64,
#  Age                -0.697647
#  WorkExperience     -6.443162
#  MonthlyIncome    -524.894477
#  dtype: float64,
#  Age                  3.026123
#  WorkExperience      -5.544021
#  MonthlyIncome     1647.670217
#  dtype: float64,
#  Age                 -7.636880
#  WorkExperience      -8.945387
#  MonthlyIncome    -4587.865347
#  dtype: float64,
#  Age                 -3.912416
#  WorkExperience      -8.045996
#  MonthlyIncome    -2414.894356
#  dtype: float64,
#  Age                -0.188325
#  WorkExperience     -7.146696
#  MonthlyIncome    -242.140663
#  dtype: float64,
#  Age                  3.535394
#  WorkExperience      -6.247485
#  MonthlyIncome     1930.395756
#  dtype: float64,
#  Age                 -7.127659
#  WorkExperience      -9.648780
#  MonthlyIncome    -4305.168081
#  dtype: float64,
#  Age                 -3.403247
#  WorkExperience      -8.749319
#  MonthlyIncome    -2132.225360
#  dtype: float64,
#  Age                0.320794
#  WorkExperience    -7.849948
#  MonthlyIncome     40.500067
#  dtype: float64,
#  Age                -10.341938
#  WorkExperience     -11.251083
#  MonthlyIncome    -6194.874780
#  dtype: float64,
#  Age                 -6.617204
#  WorkExperience     -10.351462
#  MonthlyIncome    -4021.743088
#  dtype: float64,
#  Age                 -2.892843
#  WorkExperience      -9.451931
#  MonthlyIncome    -1848.828709
#  dtype: float64,
#  Age                 0.831147
#  WorkExperience     -8.552489
#  MonthlyIncome     323.868378
#  dtype: float64,
#  Age                 -9.831636
#  WorkExperience     -11.953554
#  MonthlyIncome    -5911.534806
#  dtype: float64,
#  Age                 -6.106953
#  WorkExperience     -11.053862
#  MonthlyIncome    -3738.431448
#  dtype: float64,
#  Age                 -2.382643
#  WorkExperience     -10.154261
#  MonthlyIncome    -1565.545401
#  dtype: float64,
#  Age                 1.341296
#  WorkExperience     -9.254750
#  MonthlyIncome     607.123358
#  dtype: float64,
#  Age                 -9.321538
#  WorkExperience     -12.655744
#  MonthlyIncome    -5628.308151
#  dtype: float64,
#  Age                 -5.596906
#  WorkExperience     -11.755982
#  MonthlyIncome    -3455.233116
#  dtype: float64,
#  Age                 -1.872647
#  WorkExperience     -10.856311
#  MonthlyIncome    -1282.375389
#  dtype: float64,
#  Age                 1.851241
#  WorkExperience     -9.956729
#  MonthlyIncome     890.265053
#  dtype: float64,
#  Age                 -8.811644
#  WorkExperience     -13.357653
#  MonthlyIncome    -5345.194770
#  dtype: float64]

# %%
ypred=model.predict(Xtest)

# %%
values, counts = np.unique(ypred, return_counts=True)

for val, count in zip(values, counts):
    print(f"Value: {val}, Count: {count}")
# Out:
# Value: 0, Count: 1295
